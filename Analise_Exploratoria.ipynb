# %%
#importar a bibliotecas pandas e matplotlib
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# <ipython-input-46-9f45f057d4a1>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
#realizar upload do arquivo
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-4a529d3f-96b7-4b59-8c67-569460a07374" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a529d3f-96b7-4b59-8c67-569460a07374">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#criando dataframe
df = pd.read_excel("/content/AdventureWorks.xlsx")

# %%
#VISUALIZAR AS 5 PRIMEIRAS LINHAS.
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
#Qtde de linhas e colunas no dado
df.shape
# Out:
# (904, 16)

# %%
#tipos de dados da planilha.
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
#retornar a receita total
df["Valor Venda"].sum()
# Out:
# 5984606.1426

# %%
#criando a coluna de "Custo" que armazena o custo total do produto adquirido.
df["Custo"] = df["Custo Unitário"].mul(df["Quantidade"])

# %%
#retornando as 5 primeiras linhas e ver a nova coluna criada anteriormente.
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 0 2008-05-09 2008-05-29      199         384       18839  200805093CS607
# 1 2008-05-12 2008-05-17      306         384       19051  200805123CS567
# 2 2008-05-14 2008-05-20      306         384       19052  200805143CS576
# 3 2008-05-21 2008-05-27      306         384       19052  200805213CS576
# 4 2008-06-20 2008-06-27      306         384       19053  200806203CS586
#
#    Custo Unitário  Preço Unitário  Quantidade  Valor Desconto  Valor Venda  \
# 0          348.58           758.0           6             0.0       4548.0
# 1          348.58           758.0           6             0.0       4548.0
# 2          348.58           758.0           6             0.0       4548.0
# 3          348.58           758.0           6             0.0       4548.0
# 4          348.58           758.0           6             0.0       4548.0
#
# ...

# %%
#exibir o custo total da planilha.
round(df["Custo"].sum(),2)
# Out:
# 2486783.05

# %%
#criar coluna de lucro que armazena o lucro por venda.
df["Lucro"] = df["Valor Venda"] - df["Custo"]

# %%
#Lucro Total
round(df["Lucro"].sum(),2)
# Out:
# 3497823.09

# %%
#criando uma coluna "Tempo_Envio" que armazena o tempo de envio em dias.
df["Tempo_Envio"]=df['Data Envio']-df["Data Venda"]

# %%
#retornar o tempo médio de envio do produto por marca. Para isso seguiremos os seguintes passos:
#primeiro ter em número o templo de envio.
df['Tempo_Envio']=(df['Data Envio']-df['Data Venda']).dt.days

# %%
#segundo verificar se o tipo de dado da co,una 'Tempo_Envio' é número.
df["Tempo_Envio"].dtype
# Out:
# dtype('int64')

# %%
#Enfim retornar o tempo médio de envio dos produtos por marca.
df.groupby("Marca")["Tempo_Envio"].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo_Envio, dtype: float64

# %%
#Ver se há valores nulos e sua quantidade em cada coluna.
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo_Envio       0
# dtype: int64

# %%
#Saber lucro por qano e por marca.
df.groupby([df["Data Venda"].dt.year,"Marca"])["Lucro"].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works    3.066412e+05
#             Contoso            5.641600e+04
#             Fabrikam           1.557021e+06
# 2009        Adventure Works    4.053951e+05
#             Contoso            1.382590e+05
#             Fabrikam           1.034091e+06
# Name: Lucro, dtype: float64

# %%
#configurar exibido acima que esta em notação cientifica e que será exibido.
#ao repetir o comando anterior o dado estará alterado.
pd.options.display.float_format='{:20,.2f}'.format

# %%
#criar uma variavel para armazenar como dataframe os dados ano da venda, marca e o lucro.
#Para isso será necessario resetar o index
Lucro_Ano=df.groupby([df['Data Venda'].dt.year,"Marca"])["Lucro"].sum().reset_index
#exibir o valor da varialvel Lucro_Ano por Ano e Marca
Lucro_Ano
# Out:
# <bound method Series.reset_index of Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: Lucro, dtype: float64>

# %%
#retorna o total de pordutos vendidos
df.groupby("Produto")["Quantidade"].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
#gera gráfico em barras verticais do lucro por ano.
df.groupby(df["Data Venda"].dt.year)["Lucro"].sum().plot.bar(title="Lucro x Ano")
plt.xlabel("Ano")
plt.ylabel("Receita");

# %%
#criando varialvel que armazena as vendas de 2009. E exibi o resultado da variavel.
df_2009 = df[df["Data Venda"].dt.year == 2009]
df_2009
# Out:
#     Data Venda Data Envio  ID Loja  ID Produto  ID Cliente       No. Venda  \
# 11  2009-05-02 2009-05-14      199         384       18938  200905023CS847
# 12  2009-05-16 2009-05-27      306         384       19067  200905163CS746
# 13  2009-05-31 2009-06-12      306         384       19068  200905313CS748
# 14  2009-06-28 2009-07-11      199         384       18959  200906283CS870
# 15  2009-07-08 2009-07-12      306         384       19070  200907083CS757
# ..         ...        ...      ...         ...         ...             ...
# 890 2009-12-23 2009-12-30      199        1155       19033  200912234CS949
# 895 2009-01-11 2009-01-18      307        1155       19113  200901114CS680
# 896 2009-03-04 2009-03-15      307        1155       19117  200903044CS706
# 897 2009-06-12 2009-06-22      307        1226       19126  200906124CS716
# 898 2009-06-25 2009-07-06      307        1155       19127  200906254CS717
#
#           Custo Unitário       Preço Unitário  Quantidade  \
# ...

# %%
#gera gráfico de linhas do lucro por mês.
df_2009.groupby(df_2009["Data Venda"].dt.month)["Lucro"].sum().plot(title="Lucro x Mês")
plt.xlabel("Mês")
plt.ylabel("Lucro");

# %%
#gráfico em barras verticais do lucro por marca.
df_2009.groupby("Marca")["Lucro"].sum().plot.bar(title="Lucro x Marca")
plt.xlabel("Marca")
plt.ylabel("Lucro")
plt.xticks(rotation="horizontal");#aqui coloca o rotulo do eixo x na horizontal.

# %%
#Analise estatisticas do turno de envio.
df["Tempo_Envio"].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo_Envio, dtype: float64

# %%
#gráfico boxplot
df.boxplot(df["Tempo_Envio"]);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-0e8b425b2e96> in <cell line: 2>()
#       1 #gráfico boxplot
# ----> 2 df.boxplot(df["Tempo_Envio"]);
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     456     import matplotlib.pyplot as plt
#     457
# --> 458     ax = boxplot(
#     459         self,
#     460         column=column,
#
# ...

# %%
#grafico histograma
plt.hist(df["Tempo_Envio"]);

# %%
#tempo minimo de envio
df["Tempo_Envio" ].min()
# Out:
# 4

# %%
#tempo máximo de envio
df['Tempo_Envio'].max()
# Out:
# 20

# %%
df.to_csv("df_Venda_Novo.csv",index=False)
